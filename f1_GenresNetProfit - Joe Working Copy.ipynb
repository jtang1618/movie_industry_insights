# %% [markdown]
# # Genres that yield highest net profit

# %% [markdown]
# brief description

# %% [markdown]
# ## import the data

# %%
#necessary libraries and modules to import

import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob

# %%
#converts tsv files

tsv_file = './zippedData/rt.movie_info.tsv.gz'
convert = pd.read_table(tsv_file, delimiter='\t')
convert.to_csv('./zippedData/rt.movie_info.csv.gz')

tsv_file_r = './zippedData/rt.reviews.tsv.gz'
convert_r = pd.read_table(tsv_file_r, delimiter='\t', encoding = 'unicode_escape')
convert_r.to_csv('./zippedData/rt.reviews.csv.gz')

# %%
#importing batch data using os

csv_files = glob("./zippedData/*.csv.gz")
csv_files
# Out:
# ['./zippedData\\bom.movie_gross.csv.gz',
#  './zippedData\\imdb.name.basics.csv.gz',
#  './zippedData\\imdb.title.akas.csv.gz',
#  './zippedData\\imdb.title.basics.csv.gz',
#  './zippedData\\imdb.title.crew.csv.gz',
#  './zippedData\\imdb.title.principals.csv.gz',
#  './zippedData\\rt.movie_info.csv.gz',
#  './zippedData\\rt.reviews.csv.gz',
#  './zippedData\\tmdb.movies.csv.gz',
#  './zippedData\\tn.movie_budgets.csv.gz']

# %%
# cleaning the filenames

csv_files_dict = {} #create a dictionary of datasets
for filename in csv_files: #create a for loop to batch clean files
    filename_cleaned = os.path.basename(filename).replace(".csv", "").replace(".", "_") #remove .csv file extensions
    filename_df = pd.read_csv(filename, index_col=0, encoding='utf-8') 
    csv_files_dict[filename_cleaned] = filename_df #load .csv file as dataframe using col 1 as index and encode in utf-8 and save as the cleaned filename

# %%
print(csv_files_dict.keys())
# Out:
# dict_keys(['bom_movie_gross_gz', 'imdb_name_basics_gz', 'imdb_title_akas_gz', 'imdb_title_basics_gz', 'imdb_title_crew_gz', 'imdb_title_principals_gz', 'rt_movie_info_gz', 'rt_reviews_gz', 'tmdb_movies_gz', 'tn_movie_budgets_gz'])

# %% [markdown]
# ***Code in markdown***
#
# #create SQLite database and tables
#
# conn = sqlite3.connect("movies_db_f1.sqlite")
# def create_sql_table_from_df(df, name, conn):
#     try:
#         df.to_sql(name, conn)
#         print(f"Created table {name}")
#
#     except Exception as e:
#         print(f"could not make table {name}")
#         print(e)
#
# for name, table in datafiles_dict.items():
#     create_sql_table_from_df(table, name, conn)

# %% [markdown]
# # Looking at Top Grossing Films by Genre

# %% [markdown]
# ## Initial look at the dataset

# %%
movie_budgets_df = csv_files_dict['tn_movie_budgets_gz'] #set new dataset variable

# %%
type(movie_budgets_df) #call type of variable
# Out:
# pandas.core.frame.DataFrame

# %%
movie_budgets_df.shape #return the dimensions of the dataframe array
# Out:
# (5782, 5)

# %%
movie_budgets_df.head(10) #return the top 10 rows
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 6   Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 7   Apr 27, 2018                       Avengers: Infinity War
# 8   May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 9   Nov 17, 2017                               Justice League
# 10   Nov 6, 2015                                      Spectre
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747
# 6       $306,000,000   $936,662,225  $2,053,311,220
# 7       $300,000,000   $678,815,482  $2,048,134,200
# 8       $300,000,000   $309,420,425    $963,420,425
# 9       $300,000,000   $229,024,295    $655,945,209
# 10      $300,000,000   $200,074,175    $879,620,923

# %%
movie_budgets_df[movie_budgets_df['movie'] == 'Avatar'] #return the row containing 'Avatar' in col title 'movie'
# Out:
#     release_date   movie production_budget domestic_gross worldwide_gross
# id
# 1   Dec 18, 2009  Avatar      $425,000,000   $760,507,625  $2,776,345,279

# %%
movie_budgets_df.info() #return basic summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
movie_budgets_df.isna().sum() #sum of all the NaN values in each col
# Out:
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# The columns of production_budget, domestic_gross and worldwide_gross seem to contain numbers but their datatype is object. Also at first glance there don't seem to be any missing values

# %% [markdown]
# ## Data Cleaning

# %%
#define function called convert_amt_to_int
#cast datatype of col as string [added to avoid error], remove $, and change datatype to int64

def convert_amt_to_int(df, col):
    df[col] = df[col].astype('str').str.replace("$", "").str.replace(",", "").astype('int64') 
    return df

# %%
#make a list of cols to batch-change datatype with a for loop

money_cols = ['production_budget', 'domestic_gross', 'worldwide_gross']

for col in money_cols: 
    movie_budgets_df = convert_amt_to_int(movie_budgets_df, col)

# %%
movie_budgets_df.info() #return basic summary of dataframe to confirm datatype changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 271.0+ KB

# %%
#re-confirm no NaN values

movie_budgets_df.isna().sum()
# Out:
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Checking the value counts

# %%
#looking at the most occuring values to see if there are any weird values
#using a for loop, returning normalized values (values as a percentage of the total values) in the first 5 rows  

for col in movie_budgets_df:
    print(f'Viewing values in col: {col}')
    print(f'Top 5 values:\n{movie_budgets_df[col].value_counts(normalize = True)[:5]}')
    print("-------------------")
# Out:
# Viewing values in col: release_date
# Top 5 values:
# Dec 31, 2014    0.004151
# Dec 31, 2015    0.003978
# Dec 31, 2010    0.002594
# Dec 31, 2008    0.002421
# Dec 31, 2009    0.002248
# Name: release_date, dtype: float64
# -------------------
# Viewing values in col: movie
# Top 5 values:
# Home            0.000519
# Halloween       0.000519
# King Kong       0.000519
# Side Effects    0.000346
# The Alamo       0.000346
# Name: movie, dtype: float64
# -------------------
# Viewing values in col: production_budget
# Top 5 values:
# 20000000    0.039952
# 10000000    0.036666
# 30000000    0.030612
# 15000000    0.029920
# 25000000    0.029575
# Name: production_budget, dtype: float64
# -------------------
# Viewing values in col: domestic_gross
# Top 5 values:
# 0           0.094777
# 8000000     0.001557
# 2000000     0.001211
# 7000000     0.001211
# 10000000    0.001038
# Name: domestic_gross, dtype: float64
# -------------------
# Viewing values in col: worldwide_gross
# Top 5 values:
# 0          0.063473
# 8000000    0.001557
# 7000000    0.001038
# 2000000    0.001038
# 4000000    0.000692
# Name: worldwide_gross, dtype: float64
# -------------------

# %% [markdown]
# Now that we know our dataframe has clean data, we can start working on the logic needed to get the top 5 grossing movies. As we have the production budget available, we can create a new column which will have the profits the movie has made.

# %% [markdown]
# ### Looking at Top Grossing Films by Genre

# %% [markdown]
# #### Create a new column looking at Worldwide Gross vs. Production Budget

# %%
#add a new column 'worldwide_budget_gross_diff' by subtracting 'production_budget' from 'worldwide_gross' cols 

movie_budgets_df['worldwide_budget_gross_diff'] = movie_budgets_df['worldwide_gross'] - movie_budgets_df['production_budget']

movie_budgets_df.head() #call first 5 rows
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross  worldwide_gross  \
# id
# 1           425000000       760507625       2776345279
# 2           410600000       241063875       1045663875
# 3           350000000        42762350        149762350
# 4           330600000       459005868       1403013963
# 5           317000000       620181382       1316721747
#
#     worldwide_budget_gross_diff
# id
# 1                    2351345279
# 2                     635063875
# 3                    -200237650
# 4                    1072413963
# 5                     999721747

# %%
#### Create a new column looking at Domestic Gross vs. Production Budget

# %%
#add a new column 'domestic_budget_gross_diff' by subtracting 'production_budget' from 'domestic_gross' cols 

movie_budgets_df['domestic_budget_gross_diff'] = movie_budgets_df['domestic_gross'] - movie_budgets_df['production_budget']

movie_budgets_df.head(10) #call first 10 rows
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 6   Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 7   Apr 27, 2018                       Avengers: Infinity War
# 8   May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 9   Nov 17, 2017                               Justice League
# 10   Nov 6, 2015                                      Spectre
#
#     production_budget  domestic_gross  worldwide_gross  \
# id
# 1           425000000       760507625       2776345279
# 2           410600000       241063875       1045663875
# 3           350000000        42762350        149762350
# 4           330600000       459005868       1403013963
# 5           317000000       620181382       1316721747
# 6           306000000       936662225       2053311220
# 7           300000000       678815482       2048134200
# 8           300000000       309420425        963420425
# 9           300000000       229024295        655945209
# 10          300000000       200074175        879620923
#
#     worldwide_budget_gross_diff  domestic_budget_gross_diff
# id
# 1                    2351345279                   335507625
# 2                     635063875                  -169536125
# 3                    -200237650                  -307237650
# 4                    1072413963                   128405868
# 5                     999721747                   303181382
# 6                    1747311220                   630662225
# 7                    1748134200                   378815482
# 8                     663420425                     9420425
# 9                     355945209                   -70975705
# 10                    579620923                   -99925825

# %% [markdown]
# ### Adding Genre columns dataset

# %%
#set new dataframe from the imdb title basics dataset
imdb_title_basics_df = csv_files_dict['imdb_title_basics_gz']

# %%
imdb_title_basics_df.head() #call first 5 rows
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
#using .merge and a left join since there are different col names, and setting left_on and right_on 

movie_budget_genres_df = pd.merge(movie_budgets_df, imdb_title_basics_df, left_on=  ['movie'],
                   right_on= ['primary_title'], 
                   how = 'left')

# %%
movie_budget_genres_df.shape #return dimensions of new array
# Out:
# (7221, 12)

# %%
movie_budget_genres_df.head(50)
# Out:
#     release_date                                             movie  \
# 0   Dec 18, 2009                                            Avatar
# 1   May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2    Jun 7, 2019                                      Dark Phoenix
# 3    May 1, 2015                           Avengers: Age of Ultron
# 4   Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5   Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6   Apr 27, 2018                            Avengers: Infinity War
# 7   May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8   Nov 17, 2017                                    Justice League
# 9    Nov 6, 2015                                           Spectre
# 10  Jul 20, 2012                             The Dark Knight Rises
# 11  May 25, 2018                           Solo: A Star Wars Story
# 12   Jul 2, 2013                                   The Lone Ranger
# 13   Mar 9, 2012                                       John Carter
# 14  Nov 24, 2010                                           Tangled
# 15   May 4, 2007                                      Spider-Man 3
# 16   May 6, 2016                        Captain America: Civil War
# 17  Mar 25, 2016                Batman v Superman: Dawn of Justice
# 18  Dec 14, 2012                 The Hobbit: An Unexpected Journey
# 19  Jul 15, 2009            Harry Potter and the Half-Blood Prince
# 20  Dec 13, 2013               The Hobbit: The Desolation of Smaug
# 21  Dec 17, 2014         The Hobbit: The Battle of the Five Armies
# 22  Apr 14, 2017                           The Fate of the Furious
# 23  Jun 28, 2006                                  Superman Returns
# 24  May 26, 2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 25  Nov 14, 2008                                 Quantum of Solace
# 26   May 4, 2012                                      The Avengers
# 27   Jul 7, 2006      Pirates of the Caribbean: Dead Manâs Chest
# 28  Jun 14, 2013                                      Man of Steel
# 29  May 16, 2008          The Chronicles of Narnia: Prince Caspian
# 30   Jul 3, 2012                            The Amazing Spider-Man
# 31  May 18, 2012                                        Battleship
# 32  Jun 21, 2017                     Transformers: The Last Knight
# 33  Jun 12, 2015                                    Jurassic World
# 34  May 25, 2012                                    Men in Black 3
# 35  Jun 24, 2009               Transformers: Revenge of the Fallen
# 36  Jun 27, 2014                   Transformers: Age of Extinction
# 37  May 26, 2006                             X-Men: The Last Stand
# 38  May 14, 2010                                        Robin Hood
# 39  May 14, 2010                                        Robin Hood
# 40  May 14, 2010                                        Robin Hood
# 41  May 14, 2010                                        Robin Hood
# 42  May 14, 2010                                        Robin Hood
# 43  Dec 14, 2005                                         King Kong
# 44   Dec 7, 2007                                The Golden Compass
# 45  Feb 16, 2018                                     Black Panther
# 46  Dec 19, 1997                                           Titanic
# 47  Dec 19, 1997                                           Titanic
# 48  Jun 15, 2018                                     Incredibles 2
# 49  Dec 16, 2016                      Rogue One: A Star Wars Story
#
#     production_budget  domestic_gross  worldwide_gross  \
# 0           425000000       760507625       2776345279
# 1           410600000       241063875       1045663875
# 2           350000000        42762350        149762350
# 3           330600000       459005868       1403013963
# 4           317000000       620181382       1316721747
# 5           306000000       936662225       2053311220
# 6           300000000       678815482       2048134200
# 7           300000000       309420425        963420425
# 8           300000000       229024295        655945209
# 9           300000000       200074175        879620923
# 10          275000000       448139099       1084439099
# 11          275000000       213767512        393151347
# 12          275000000        89302115        260002115
# 13          275000000        73058679        282778100
# 14          260000000       200821936        586477240
# 15          258000000       336530303        894860230
# 16          250000000       408084349       1140069413
# 17          250000000       330360194        867500281
# 18          250000000       303003568       1017003568
# 19          250000000       302089278        935213767
# 20          250000000       258366855        960366855
# 21          250000000       255119788        945577621
# 22          250000000       225764765       1234846267
# 23          232000000       200120000        374085065
# 24          230000000       172558876        788241137
# 25          230000000       169368427        591692078
# 26          225000000       623279547       1517935897
# 27          225000000       423315812       1066215812
# 28          225000000       291045518        667999518
# 29          225000000       141621490        417341288
# 30          220000000       262030663        757890267
# 31          220000000        65233400        313477717
# 32          217000000       130168683        602893340
# 33          215000000       652270625       1648854864
# 34          215000000       179020854        654213485
# 35          210000000       402111870        836519699
# 36          210000000       245439076       1104039076
# 37          210000000       234362462        459260946
# 38          210000000       105487148        322459006
# 39          210000000       105487148        322459006
# 40          210000000       105487148        322459006
# 41          210000000       105487148        322459006
# 42          210000000       105487148        322459006
# 43          207000000       218080025        550517357
# 44          205000000        70107728        367262558
# 45          200000000       700059566       1348258224
# 46          200000000       659363944       2208208395
# 47          200000000       659363944       2208208395
# 48          200000000       608581744       1242520711
# 49          200000000       532177324       1049102856
#
#     worldwide_budget_gross_diff  domestic_budget_gross_diff  \
# 0                    2351345279                   335507625
# 1                     635063875                  -169536125
# 2                    -200237650                  -307237650
# 3                    1072413963                   128405868
# 4                     999721747                   303181382
# 5                    1747311220                   630662225
# 6                    1748134200                   378815482
# 7                     663420425                     9420425
# 8                     355945209                   -70975705
# 9                     579620923                   -99925825
# 10                    809439099                   173139099
# 11                    118151347                   -61232488
# 12                    -14997885                  -185697885
# 13                      7778100                  -201941321
# 14                    326477240                   -59178064
# 15                    636860230                    78530303
# 16                    890069413                   158084349
# 17                    617500281                    80360194
# 18                    767003568                    53003568
# 19                    685213767                    52089278
# 20                    710366855                     8366855
# 21                    695577621                     5119788
# 22                    984846267                   -24235235
# 23                    142085065                   -31880000
# 24                    558241137                   -57441124
# 25                    361692078                   -60631573
# 26                   1292935897                   398279547
# 27                    841215812                   198315812
# 28                    442999518                    66045518
# 29                    192341288                   -83378510
# 30                    537890267                    42030663
# 31                     93477717                  -154766600
# 32                    385893340                   -86831317
# 33                   1433854864                   437270625
# 34                    439213485                   -35979146
# 35                    626519699                   192111870
# 36                    894039076                    35439076
# 37                    249260946                    24362462
# 38                    112459006                  -104512852
# 39                    112459006                  -104512852
# 40                    112459006                  -104512852
# 41                    112459006                  -104512852
# 42                    112459006                  -104512852
# 43                    343517357                    11080025
# 44                    162262558                  -134892272
# 45                   1148258224                   500059566
# 46                   2008208395                   459363944
# 47                   2008208395                   459363944
# 48                   1042520711                   408581744
# 49                    849102856                   332177324
#
#                                        primary_title  \
# 0                                             Avatar
# 1        Pirates of the Caribbean: On Stranger Tides
# 2                                       Dark Phoenix
# 3                            Avengers: Age of Ultron
# 4                                                NaN
# 5                                                NaN
# 6                             Avengers: Infinity War
# 7                                                NaN
# 8                                     Justice League
# 9                                            Spectre
# 10                             The Dark Knight Rises
# 11                           Solo: A Star Wars Story
# 12                                   The Lone Ranger
# 13                                       John Carter
# 14                                           Tangled
# 15                                               NaN
# 16                        Captain America: Civil War
# 17                Batman v Superman: Dawn of Justice
# 18                 The Hobbit: An Unexpected Journey
# 19                                               NaN
# 20               The Hobbit: The Desolation of Smaug
# 21         The Hobbit: The Battle of the Five Armies
# 22                           The Fate of the Furious
# 23                                               NaN
# 24  Pirates of the Caribbean: Dead Men Tell No Tales
# 25                                               NaN
# 26                                      The Avengers
# 27                                               NaN
# 28                                      Man of Steel
# 29                                               NaN
# 30                            The Amazing Spider-Man
# 31                                        Battleship
# 32                     Transformers: The Last Knight
# 33                                    Jurassic World
# 34                                    Men in Black 3
# 35                                               NaN
# 36                   Transformers: Age of Extinction
# 37                                               NaN
# 38                                        Robin Hood
# 39                                        Robin Hood
# 40                                        Robin Hood
# 41                                        Robin Hood
# 42                                        Robin Hood
# 43                                         King Kong
# 44                                               NaN
# 45                                     Black Panther
# 46                                           Titanic
# 47                                           Titanic
# 48                                     Incredibles 2
# 49                      Rogue One: A Star Wars Story
#
#                                       original_title  start_year  \
# 0                                              Abatâ      2011.0
# 1        Pirates of the Caribbean: On Stranger Tides      2011.0
# 2                                       Dark Phoenix      2019.0
# 3                            Avengers: Age of Ultron      2015.0
# 4                                                NaN         NaN
# 5                                                NaN         NaN
# 6                             Avengers: Infinity War      2018.0
# 7                                                NaN         NaN
# 8                                     Justice League      2017.0
# 9                                            Spectre      2015.0
# 10                             The Dark Knight Rises      2012.0
# 11                           Solo: A Star Wars Story      2018.0
# 12                                   The Lone Ranger      2013.0
# 13                                       John Carter      2012.0
# 14                                           Tangled      2010.0
# 15                                               NaN         NaN
# 16                        Captain America: Civil War      2016.0
# 17                Batman v Superman: Dawn of Justice      2016.0
# 18                 The Hobbit: An Unexpected Journey      2012.0
# 19                                               NaN         NaN
# 20               The Hobbit: The Desolation of Smaug      2013.0
# 21         The Hobbit: The Battle of the Five Armies      2014.0
# 22                           The Fate of the Furious      2017.0
# 23                                               NaN         NaN
# 24  Pirates of the Caribbean: Dead Men Tell No Tales      2017.0
# 25                                               NaN         NaN
# 26                                      The Avengers      2012.0
# 27                                               NaN         NaN
# 28                                      Man of Steel      2013.0
# 29                                               NaN         NaN
# 30                            The Amazing Spider-Man      2012.0
# 31                                        Battleship      2012.0
# 32                     Transformers: The Last Knight      2017.0
# 33                                    Jurassic World      2015.0
# 34                                    Men in Black 3      2012.0
# 35                                               NaN         NaN
# 36                   Transformers: Age of Extinction      2014.0
# 37                                               NaN         NaN
# 38                                        Robin Hood      2010.0
# 39                                        Robin Hood      2013.0
# 40                                        Robin Hood      2018.0
# 41                                        Robin Hood      2018.0
# 42                                        Robin Hood      2017.0
# 43                                         King Kong      2018.0
# 44                                               NaN         NaN
# 45                                     Black Panther      2018.0
# 46                                           Titanic      2012.0
# 47                                           Titanic      2018.0
# 48                                     Incredibles 2      2018.0
# 49                                         Rogue One      2016.0
#
#     runtime_minutes                      genres
# 0              93.0                      Horror
# 1             136.0    Action,Adventure,Fantasy
# 2             113.0     Action,Adventure,Sci-Fi
# 3             141.0     Action,Adventure,Sci-Fi
# 4               NaN                         NaN
# 5               NaN                         NaN
# 6             149.0     Action,Adventure,Sci-Fi
# 7               NaN                         NaN
# 8             120.0    Action,Adventure,Fantasy
# 9             148.0   Action,Adventure,Thriller
# 10            164.0             Action,Thriller
# 11            135.0    Action,Adventure,Fantasy
# 12            150.0    Action,Adventure,Western
# 13            132.0     Action,Adventure,Sci-Fi
# 14            100.0  Adventure,Animation,Comedy
# 15              NaN                         NaN
# 16            147.0     Action,Adventure,Sci-Fi
# 17            151.0    Action,Adventure,Fantasy
# 18            169.0    Adventure,Family,Fantasy
# 19              NaN                         NaN
# 20            161.0           Adventure,Fantasy
# 21            144.0           Adventure,Fantasy
# 22            136.0       Action,Crime,Thriller
# 23              NaN                         NaN
# 24            129.0    Action,Adventure,Fantasy
# 25              NaN                         NaN
# 26            143.0     Action,Adventure,Sci-Fi
# 27              NaN                         NaN
# 28            143.0     Action,Adventure,Sci-Fi
# 29              NaN                         NaN
# 30            136.0     Action,Adventure,Sci-Fi
# 31            131.0     Action,Adventure,Sci-Fi
# 32            154.0     Action,Adventure,Sci-Fi
# 33            124.0     Action,Adventure,Sci-Fi
# 34            106.0     Action,Adventure,Comedy
# 35              NaN                         NaN
# 36            165.0     Action,Adventure,Sci-Fi
# 37              NaN                         NaN
# 38            140.0      Action,Adventure,Drama
# 39             92.0                Action,Drama
# 40            116.0   Action,Adventure,Thriller
# 41              NaN                         NaN
# 42             60.0    Action,Adventure,History
# 43              NaN            Action,Adventure
# 44              NaN                         NaN
# 45            134.0     Action,Adventure,Sci-Fi
# 46              NaN                   Adventure
# 47            115.0                      Family
# 48            118.0  Action,Adventure,Animation
# 49            133.0     Action,Adventure,Sci-Fi

# %%
movie_budget_genres_df.info() # return basic summary of new dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 0 to 7220
# Data columns (total 12 columns):
# release_date                   7221 non-null object
# movie                          7221 non-null object
# production_budget              7221 non-null int64
# domestic_gross                 7221 non-null int64
# worldwide_gross                7221 non-null int64
# worldwide_budget_gross_diff    7221 non-null int64
# domestic_budget_gross_diff     7221 non-null int64
# primary_title                  3815 non-null object
# original_title                 3814 non-null object
# start_year                     3815 non-null float64
# runtime_minutes                3328 non-null float64
# genres                         3743 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 733.4+ KB

# %%
movie_budget_genres_df.notna()
# Out:
#       release_date  movie  production_budget  domestic_gross  worldwide_gross  \
# 0             True   True               True            True             True
# 1             True   True               True            True             True
# 2             True   True               True            True             True
# 3             True   True               True            True             True
# 4             True   True               True            True             True
# ...            ...    ...                ...             ...              ...
# 7216          True   True               True            True             True
# 7217          True   True               True            True             True
# 7218          True   True               True            True             True
# 7219          True   True               True            True             True
# 7220          True   True               True            True             True
#
#       worldwide_budget_gross_diff  domestic_budget_gross_diff  primary_title  \
# 0                            True                        True           True
# 1                            True                        True           True
# 2                            True                        True           True
# 3                            True                        True           True
# 4                            True                        True          False
# ...                           ...                         ...            ...
# 7216                         True                        True           True
# 7217                         True                        True          False
# 7218                         True                        True          False
# 7219                         True                        True           True
# 7220                         True                        True          False
#
#       original_title  start_year  runtime_minutes  genres
# 0               True        True             True    True
# 1               True        True             True    True
# 2               True        True             True    True
# 3               True        True             True    True
# 4              False       False            False   False
# ...              ...         ...              ...     ...
# 7216            True        True             True    True
# 7217           False       False            False   False
# 7218           False       False            False   False
# 7219            True        True             True    True
# 7220           False       False            False   False
#
# [7221 rows x 12 columns]

# %% [markdown]
# ## By Genre, which films yield highest net profit?

# %% [markdown]
# short description

# %% [markdown]
# ### Genre performance by year

# %% [markdown]
#     * Review net loss
#     * Review net gain

# %% [markdown]
# ### Genre performance by runtime

# %% [markdown]
#     * Review net loss
#     * Review net gain

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Dealing with datatypes

# %% [markdown]
# ### Checking the value counts

# %% [markdown]
# ### Result: By Genre, which films yield the highest net profit?

# %% [markdown]
# ## Data Visualization
